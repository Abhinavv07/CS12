# %%
def lenwords(s):
    x = s.split()
    z = []
    for i in x:
        z.append(len(i))
    return tuple(z)
print(lenwords("hello world"))
# Out:
# (5, 5)

# %%
#Random module
import random
print(random.randint(5,6))
print(random.randrange(4,10,2))

lst = ["Helo","my","name","is","abhinav"]
print(random.choice(lst))
# Out:
# 6
# 6
# Helo
